# %%
# !pip install tensorflow opencv-python numpy matplotlib scikit-learn tensorflow-datasets
# Out:
# ...
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'R:\\Annaconda new\\Lib\\site-packages\\cv2\\cv2.pyd'
# Consider using the `--user` option or check the permissions.
# ...
#   Using cached opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
# Using cached opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl (39.5 MB)
# ...
#    ---------------------------------------- 0.0/5.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/5.3 MB ? eta -:--:--
#    ----- ---------------------------------- 0.8/5.3 MB 2.6 MB/s eta 0:00:02
#    --------- ------------------------------ 1.3/5.3 MB 2.4 MB/s eta 0:00:02
#    ----------- ---------------------------- 1.6/5.3 MB 2.4 MB/s eta 0:00:02
#    --------------- ------------------------ 2.1/5.3 MB 2.3 MB/s eta 0:00:02
# ...
